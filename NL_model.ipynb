# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

BASE_URL = "https://www.lrt.lt"
HEADERS = {"User-Agent": "Mozilla/5.0"}
MAX_ARTICLES = 250
CRAWL_DELAY = 0.5  # seconds

visited_pages = set()
article_links = set()

def get_full_url(href):
    if href.startswith("http"):
        return href
    elif href.startswith("/"):
        return BASE_URL + href
    return None

def extract_links_from_page(url):
    try:
        response = requests.get(url, headers=HEADERS, timeout=10)
        response.encoding = 'utf-8'
        soup = BeautifulSoup(response.text, "html.parser")
    except Exception as e:
        print(f"Failed to load {url}: {e}")
        return []

    links = []
    for a in soup.find_all("a", href=True):
        href = a['href']
        full_url = get_full_url(href)
        if not full_url or BASE_URL not in full_url:
            continue
        if "/naujienos/" in full_url and full_url.count("/") > 4:
            article_links.add(full_url)
        elif full_url not in visited_pages:
            links.append(full_url)

    return links

def parse_article(url):
    try:
        res = requests.get(url, headers=HEADERS, timeout=10)
        res.encoding = 'utf-8'
        soup = BeautifulSoup(res.text, "html.parser")
        title = soup.find("h1").get_text(strip=True) if soup.find("h1") else "No Title"
        paragraphs = soup.find_all("p")
        text = "\n".join(p.get_text(strip=True) for p in paragraphs if len(p.get_text(strip=True)) > 40)
        return {"title": title, "url": url, "text": text}
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

# Start crawling from homepage
to_visit = [BASE_URL]

while to_visit and len(article_links) < MAX_ARTICLES:
    current_url = to_visit.pop(0)
    if current_url in visited_pages:
        continue
    visited_pages.add(current_url)

    print(f"Visiting: {current_url} | Articles found: {len(article_links)}")
    new_links = extract_links_from_page(current_url)
    to_visit.extend(new_links)
    time.sleep(CRAWL_DELAY)

print(f"Collected {len(article_links)} article links. Starting to scrape content...")

# Scrape article content
articles = []
for i, url in enumerate(list(article_links)[:MAX_ARTICLES]):
    print(f"[{i+1}] Scraping: {url}")
    article = parse_article(url)
    if article:
        articles.append(article)
    time.sleep(CRAWL_DELAY)

# Save to CSV
with open("/content/drive/MyDrive/lrt_articles.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["title", "url", "text"])
    writer.writeheader()
    writer.writerows(articles)

print("Saved lrt.lt articles to lrt_articles.csv")
# Out:
# Visiting: https://www.lrt.lt | Articles found: 0
# Visiting: https://www.lrt.lt/programa | Articles found: 178
# Visiting: https://www.lrt.lt/ | Articles found: 178
# Visiting: https://www.lrt.lt/en/news-in-english | Articles found: 180
# Visiting: https://www.lrt.lt/ru/novosti | Articles found: 180
# Visiting: https://www.lrt.lt/pl/wiadomosci | Articles found: 180
# Visiting: https://www.lrt.lt/ua/novini | Articles found: 180
# Visiting: https://www.lrt.lt/paieska | Articles found: 180
# Visiting: https://www.lrt.lt/naujienos/lietuvoje | Articles found: 180
# Visiting: https://www.lrt.lt/lituanica/aktualijos/751/2553116/pakistano-karacio-mieste-atidarytas-lietuvos-garbes-konsulatas | Articles found: 187
# Visiting: https://www.lrt.lt/lituanica/aktualijos | Articles found: 188
# Visiting: https://www.lrt.lt/naujienos/verslas | Articles found: 188
# Visiting: https://www.lrt.lt/naujienos/sveikata | Articles found: 204
# Visiting: https://www.lrt.lt/naujienos/svietimas | Articles found: 204
# Visiting: https://www.lrt.lt/naujienos/laisvalaikis | Articles found: 204
# Visiting: https://www.lrt.lt/naujienos/sportas | Articles found: 206
# Visiting: https://www.lrt.lt/naujienos/eismas | Articles found: 227
# Visiting: https://www.lrt.lt/naujienos/mokslas-ir-it | Articles found: 235
# Collected 251 article links. Starting to scrape content...
# [1] Scraping: https://www.lrt.lt/naujienos/sveikata/682/2553106/priezastys-kodel-vaikai-pradeda-vartoti-psichoaktyvias-medziagas-nuo-smalsumo-iki-nerimo
# [2] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2552165/princas-harry-pralaimejo-apeliacija-del-jungtines-karalystes-policijos-apsaugos
# [3] Scraping: https://www.lrt.lt/naujienos/eismas/7/2548119/technines-apziuros-pokyciai-lietuvai-butu-itin-nepalankus-paliestu-1-4-mln-automobiliu
# [4] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2550417/putino-siulomos-paliaubos-triukas-ir-bandymas-isvengti-pazeminimo
# [5] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2550230/5-vaikus-auginanti-energinga-kauniete-kai-nelieka-laiko-sau-yra-svarbiausia-jo-rasti
# [6] Scraping: https://www.lrt.lt/naujienos/sportas/10/2466395/is-dakaro-grizes-paulavicius-papasakojo-apie-nuotykius-su-medaliu-ir-ateities-planus
# [7] Scraping: https://www.lrt.lt/naujienos/verslas/4/2528907/birzos-laikmatis-trumpo-politika-darosi-vis-skaudesne-ekonomikoms
# [8] Scraping: https://www.lrt.lt/naujienos/kultura/12/2539746/pravieniskese-auges-teatro-apdovanojima-pelnes-vinciunas-man-tai-yra-vaikystes-vieta
# [9] Scraping: https://www.lrt.lt/naujienos/sportas/10/2438362/2024-ieji-lietuvos-sporte-nuo-medaliu-spindesio-paryziuje-iki-kvapa-gniauzianciu-rekordu
# [10] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2553022/saltinis-izraelio-vyriausybe-patvirtino-plana-uzkariauti-gazos-ruoza
# [11] Scraping: https://www.lrt.lt/naujienos/verslas/4/2546379/kinijos-vejo-ir-saules-energijos-pajegumai-pirmakart-virsijo-iskastinio-kuro
# [12] Scraping: https://www.lrt.lt/naujienos/verslas/4/2553019/ltg-grupe-siemet-valstybei-ismokes-33-mln-euru-dividendu
# [13] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2527165/aplinkos-psichologe-apie-niuria-ateiti-toliau-tersime-matysime-zmoniu-kancias
# [14] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552849/siauliu-bankas-pakeite-pavadinima-i-artea
# [15] Scraping: https://www.lrt.lt/naujienos/eismas/7/2536249/vilniaus-vyr-architekte-apie-besiplecianti-miesta-daugiau-nei-30-metu-gyvenome-chaose
# [16] Scraping: https://www.lrt.lt/naujienos/sportas/10/2446104/linksmuosius-kalnelius-2024-aisiais-prisiminusi-bucinskyte-is-skausmu-geriausiai-mokomes
# [17] Scraping: https://www.lrt.lt/naujienos/eismas/7/2547928/vairuotojams-nuo-liepos-brangs-technine-apziura
# [18] Scraping: https://www.lrt.lt/naujienos/eismas/7/2549285/elektromobiliu-segmente-nauja-banga-alkunemis-stumdosi-vis-daugiau-gamintoju
# [19] Scraping: https://www.lrt.lt/naujienos/kultura/12/2552719/libertas-klimka-apie-pirmaja-geguzes-menesio-savaite
# [20] Scraping: https://www.lrt.lt/naujienos/muzika/680/2552663/jautri-donato-montvydo-padeka-mamai-pristato-daina-ir-klipa-mazais-zingsneliais
# [21] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2543326/sena-dnr-tirianti-bos-apie-tai-kas-europa-uzkrete-sifiliu-ir-lietuvoje-rasta-reta-liga
# [22] Scraping: https://www.lrt.lt/naujienos/muzika/680/2552665/dainininkas-juozas-butnorius-su-vaikais-irase-kurini-mamai-akys-buvo-pilnos-asaru
# [23] Scraping: https://www.lrt.lt/naujienos/verslo-pozicija/692/2551908/robertas-janickas-elektros-energijos-sutrikimas-pietu-europoje-gera-pamoka
# [24] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2550875/gaisras-buvusiame-vilniaus-planetariume
# [25] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552780/zibenas-po-pergalingo-vilniaus-derbio-atrodo-eiline-pergale-bet-klubui-ji-svarbi
# [26] Scraping: https://www.lrt.lt/naujienos/eismas/7/2550620/betonkeje-tarp-vilniaus-ir-moletu-bus-irengtas-2plus1-kelias-kas-tai-yra
# [27] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2525165/82-eju-stase-pati-isirenge-priedanga-dabar-niekas-nebaisu-pasislepti-priimtu-ir-kaimyne
# [28] Scraping: https://www.lrt.lt/naujienos/pozicija/679/2543259/ieva-budraite-zemes-diena-apie-tyla-kuria-pasinaudoja-galingieji
# [29] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552733/riteriai-nesustabde-kauno-zalgirio-puolimo
# [30] Scraping: https://www.lrt.lt/naujienos/kultura/12/2537622/su-netflix-dirbanti-intymumo-koordinatore-nuogas-kunas-kine-neatrodo-labai-gerai
# [31] Scraping: https://www.lrt.lt/naujienos/verslo-pozicija/692/2551674/vytenis-lapinskas-balandi-blogiausia-ir-geriausia-s-p-akciju-indekso-diena
# [32] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552862/rumunijos-prezidento-rinkimai-pirma-tura-laimejo-krastutiniu-desiniuju-paziuru-kandidatas
# [33] Scraping: https://www.lrt.lt/naujienos/lrt-tyrimai/5/2543525/lrt-tyrimas-valdzia-gynybai-nori-skolintis-bet-zemaitaitis-mato-bobutes-paskola
# [34] Scraping: https://www.lrt.lt/naujienos/verslas/4/2548068/i-lietuva-patekti-norinciu-uzsienieciu-mulkinimas-pavogtas-zinomas-vardas-ir-nuotraukos
# [35] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552984/elektros-jungti-su-sgd-terminalu-uz-19-3-mln-euru-statys-kauno-tiltai
# [36] Scraping: https://www.lrt.lt/naujienos/sveikata/682/2550683/eileje-pas-gydytojus-specialistus-daugumai-tenka-laukti-2-3-savaites-nerima-kelia-vyrai
# [37] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2550528/juodosios-nasles-rusijoje-moterys-vilioja-karius-del-pomirtiniu-ismoku
# [38] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552972/gazos-ruozo-civilines-gynybos-agentura-per-izraelio-smugius-zuvo-maziausiai-19-zmoniu
# [39] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2551660/vu-mokslininkai-atrado-ir-zurnale-nature-aprase-unikalios-sandaros-signaline-molekule
# [40] Scraping: https://www.lrt.lt/naujienos/verslo-pozicija/692/2550215/matas-laukevicius-investuotojus-neramina-prekybos-karu-poveikis-pasauliniam-augimui
# [41] Scraping: https://www.lrt.lt/naujienos/verslas/4/2549351/birzos-laikmatis-trumpo-komanda-ketina-perziureti-muitus-automobiliu-gamintojams
# [42] Scraping: https://www.lrt.lt/naujienos/sportas/10/2549963/trinchieri-vieta-uzemes-sabonis-su-trenerio-isvarymu-vel-susikaupeme
# [43] Scraping: https://www.lrt.lt/naujienos/sportas/10/2535990/is-kitos-planetos-alekna-apie-pasaulio-rekordus-fenomenalu-denny-ir-stanionio-kova
# [44] Scraping: https://www.lrt.lt/naujienos/sportas/10/2463835/i-lietuva-is-dakaro-kanciu-grizes-zala-kad-ir-koks-butum-zveris-spaudimui-gali-pasiduoti
# [45] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552815/kinijoje-apvirtus-laivams-zuvo-trys-zmones-60-suzeista
# [46] Scraping: https://www.lrt.lt/naujienos/sportas/10/2547931/taip-nutinka-retai-rekordo-magijos-pakyleta-juskeviciute-nori-zengti-skujytes-pedsakais
# [47] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552688/buves-kariuomenes-vadas-tutkus-ikure-asociacija-alternatyva-lietuvai
# [48] Scraping: https://www.lrt.lt/naujienos/tavo-lrt/15/2552079/tinklalaideje-nuolat-pildoma-diskusija-apie-profesine-etika-ir-zurnalisto-sazine
# [49] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2551580/veido-tyrimai-ar-yra-tokiu-bruozu-kurie-nesikeicia-visa-gyvenima
# [50] Scraping: https://www.lrt.lt/naujienos/eismas/7/2543809/ilgai-zadeta-siaurine-gatve-vilniuje-aiskeja-kada-gali-prasideti-jos-tiesimas
# [51] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552882/hjustone-lemiamas-rungtynes-laimejusi-golden-state-warriors-vakaru-pusfinalyje
# [52] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552852/prasideda-gelezinis-vilkas-2025-i-pratybos-jose-dalyvaus-apie-3-7-tukst-kariu
# [53] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552764/namus-apgynes-neptunas-neuzleido-kedainieciams-astuntosios-vietos
# [54] Scraping: https://www.lrt.lt/naujienos/kultura/12/2551439/medzio-drozejas-cesnulis-pristato-kompozicija-ciurlionio-150-osioms-gimimo-metinems
# [55] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2534065/zymus-pasaulyje-imunologas-skiepai-nesukelia-autizmo-o-ju-salutiniai-poveikiai-neirodyti
# [56] Scraping: https://www.lrt.lt/naujienos/sportas/10/2551558/varzovus-triuskine-lietuvos-ledo-ritulininkai-iskovojo-auksa-ir-bilieta-aukstyn
# [57] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552913/trumpas-nurode-vel-atidaryti-liudnai-pagarsejusi-alkatraso-kalejima
# [58] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552751/nutolusias-saules-elektrines-isigije-gyventojai-prasymus-paramai-gali-teikti-iki-rudens
# [59] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552768/policija-uzkirto-kelia-bandymui-surengti-sprogdinima-lady-gaga-koncerte-brazilijoje
# [60] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2550767/po-gaisro-tvarkoma-energesman-teritorija
# [61] Scraping: https://www.lrt.lt/naujienos/verslas/4/2506768/skrydziu-vadovo-darbo-uzkulisiai-jo-komandoms-pakluso-net-jav-prezidentinis-orlaivis
# [62] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552932/trumpas-pasiule-pasiusti-jav-karius-i-meksika-bet-sheinbaum-nesutiko
# [63] Scraping: https://www.lrt.lt/naujienos/kultura/12/2552488/savivaldybe-nezino-kur-yra-vilniaus-tapybos-pleneru-metu-nutapyti-garsiu-menininku-darbai
# [64] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2540123/interjero-dizainere-50-pilku-atspalviu-jau-iskeliauja-uztarnauto-poilsio
# [65] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2540210/laboratoriniu-deimantu-bumas-zymiai-pigesni-bet-ar-tikrai-tokie-patys-kaip-naturalus
# [66] Scraping: https://www.lrt.lt/naujienos/sportas/10/2549652/olimpinio-aukso-link-zengiantis-juska-nenoriu-buti-kitas-phelpsas-noriu-buti-kitas-juska
# [67] Scraping: https://www.lrt.lt/naujienos/kultura/12/2552067/mokykla-mano-namai-siauliuose-eksponuojamos-sovietmeciu-draustos-sontos-fotografijos
# [68] Scraping: https://www.lrt.lt/naujienos/kultura/12/2552965/siauliuose-vyks-festivalis-konkursas-ausrine-zvaigzde-nuo-tradiciju-iki-premjeru
# [69] Scraping: https://www.lrt.lt/naujienos/sportas/10/2550046/sukurineje-vonioje-po-triumfo-ismaudytas-jasikevicius-tokios-akimirkos-viska-atperka
# [70] Scraping: https://www.lrt.lt/naujienos/svietimas/45/2553118/valstybes-kontrole-pernai-mokyklose-vienu-kompiuteriu-naudojosi-keturi-mokiniai
# [71] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2550823/baltarusijos-pasienyje-rasti-apire-triju-zmoniu-kunai-del-dvieju-aiskinasi-baltarusiai
# [72] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552762/esame-vidutiniokai-lietuvoje-moterys-uzdirba-maziau-uz-vyrus-bet-reformos-tai-keis
# [73] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552896/huciai-pranese-apie-jav-smugius-sanoje-ir-jos-apylinkese
# [74] Scraping: https://www.lrt.lt/naujienos/pozicija/679/2550727/jurgis-valiukevicius-30-metu-socialinio-dialogo-ka-pasiekeme-ir-kur-einame
# [75] Scraping: https://www.lrt.lt/naujienos/kultura/12/2552899/trumpas-pareiske-isakysias-ivesti-100-proc-muita-visiems-uzsienyje-sukurtiems-filmams
# [76] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552870/vesios-dienos-ir-astriomis-salnomis-pazenklintos-naktys-ilgam-isitvirtina-zvarbus-orai
# [77] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2553032/paluckas-nemano-kad-sia-savaite-bus-naujienu-del-naujo-poligono-vietos
# [78] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2526059/privati-sleptuve-savame-kieme-kaina-nuo-60-tukst-euru-apsaugo-nuo-ivairiu-gresmiu
# [79] Scraping: https://www.lrt.lt/naujienos/nuomones/3/2544759/silvestras-dikcius-popiezius-ir-ekologija-ar-pranciskaus-zodziai-nenutils-su-juo
# [80] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552759/unesco-nikaragva-pasitrauke-is-organizacijos-del-spaudai-suteikto-apdovanojimo
# [81] Scraping: https://www.lrt.lt/naujienos/kultura/12/2552991/jubilieju-minintis-seilius-esu-laimingas-apsuptas-savo-moteru-meiles-ir-mylintis
# [82] Scraping: https://www.lrt.lt/naujienos/verslas/4/2548032/gaisras-atlieku-tvarkymo-gamykloje-vilniuje-uzgesintas
# [83] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552826/egles-rankininkes-pateko-i-lmrl-finala-cempioniu-ir-autsaideriu-dvikovoje-lygybe
# [84] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552749/sabatauskas-nemanau-kad-pokyciai-del-parlamentaru-nelieciamybes-galetu-buti-igyvendinami
# [85] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552163/trumpo-uzsienio-politikos-komandos-supurtymas-kas-laukia-toliau
# [86] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2553022/saltinis-izraelio-vyriausybe-patvirtino-plana-isplesti-karines-operacijas-gazos-ruoze
# [87] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552816/izraelis-patvirtino-kad-plesti-karui-gazos-ruoze-pasauke-desimtis-tukstanciu-rezervistu
# [88] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552818/tinklininkes-dumbauskaite-ir-grudzinskaite-filipinuose-iskovojo-bronzos-medalius
# [89] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2551264/suo-kaip-zmogus-isskirtineje-parodoje-demesys-istorijai-kuri-vizgina-uodega
# [90] Scraping: https://www.lrt.lt/naujienos/lrt-tyrimai/5/2524806/lrt-tyrimas-seseliu-zmones-kvietimai-dirbti-augina-ir-nelegalu-buri
# [91] Scraping: https://www.lrt.lt/naujienos/lrt-tyrimai/5/2544818/tarptautinis-tyrimas-lietuvio-kelias-iki-gru-hibridines-operacijos
# [92] Scraping: https://www.lrt.lt/naujienos/sportas/10/2443410/gimimo-diena-geriausiu-lietuvos-paralimpieciu-tapes-bareikis-tai-yra-istorinis-pasiekimas
# [93] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552649/neblaivi-vairavusi-buvusi-viceministre-urbanaviciene-praso-teismo-jos-nebausti-griezciau
# [94] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2549315/australijoje-po-nacionaliniame-parke-kilusio-gaisro-snaiperiai-nusove-iki-700-koalu
# [95] Scraping: https://www.lrt.lt/naujienos/verslas/4/2553043/birzos-laikmatis-trumpas-ragina-powella-mazinti-palukanu-normas
# [96] Scraping: https://www.lrt.lt/naujienos/tavo-lrt/15/2552014/grupe-frizz-cikle-lrt-opus-jaunatis
# [97] Scraping: https://www.lrt.lt/naujienos/verslas/4/2550157/nuomininke-pusmeti-nemoka-uz-nuoma-bet-buto-savininkai-negali-jos-iskraustyti
# [98] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2543489/silumos-rekordams-tapus-kone-kasdienybe-specialistai-ispeja-apie-augancia-sausru-gresme
# [99] Scraping: https://www.lrt.lt/naujienos/verslas/4/2530767/du-italai-kuria-viesuju-pirkimu-perversma-lietuvoje-klauskite-kaip-chatgpt
# [100] Scraping: https://www.lrt.lt/naujienos/sportas/10/2549902/lietuviai-praleido-pirma-ivarti-ledo-ritulio-cempionate-taciau-isliko-pergalingame-kelyje
# [101] Scraping: https://www.lrt.lt/naujienos/kultura/12/2537211/mantas-balakauskas-dygiosios-melancholijos-poezija
# [102] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2540209/10-faktu-apie-gyvybe-zemeje-kuriu-nezinojote
# [103] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552711/suduvos-ir-panevezio-akistatoje-nepasizymejo-ne-viena-komanda
# [104] Scraping: https://www.lrt.lt/naujienos/verslas/4/2551693/birzos-laikmatis-geri-microsoft-rezultatai-sugrazino-technologiju-akcijas-i-augima
# [105] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2553073/robotikos-nacionalinio-finalo-laimetojams-kelialapis-i-varzybas-singapure
# [106] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2551694/jubilieju-atsventes-edmundas-kucinskas-nei-sirdyje-nei-fiziskai-nesijauciu-70-ies
# [107] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2533956/mazuju-simpanziu-suksniai-yra-daug-panasesni-i-zmoniu-kalba-nei-iki-siol-maneme
# [108] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2551937/nustatyta-kad-20-tukst-hektaru-zemes-aplink-cornobyli-ir-vel-tinkama-ukininkavimui
# [109] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552743/svarbiu-metu-vilkus-uzdominaves-rytas-treciakart-si-sezona-laimejo-vilniaus-derbyje
# [110] Scraping: https://www.lrt.lt/naujienos/verslas/4/2551428/ziniasklaida-is-vilniaus-i-stambula-turejes-skristi-lektuvas-grizo-atgal-i-vilniu
# [111] Scraping: https://www.lrt.lt/naujienos/sportas/10/2550547/po-pasirodziusios-informacijos-apie-galima-lkf-rysi-su-paceso-verslu-balciuno-atsakymas
# [112] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2536489/mokslininkai-ivardijo-kokie-kiausiniu-dazymo-budai-nera-saugus-kojiniu-geriau-nenaudoti
# [113] Scraping: https://www.lrt.lt/naujienos/kultura/12/2545222/vytautui-miskiniui-oficialiai-suteiktas-garbes-piliecio-vardas
# [114] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2483327/savaitgalio-pietums-sefo-pasiulymas-anties-krutinele-su-vaisiais-ir-darzovemis
# [115] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552959/vokietijoje-minetos-80-osios-dachau-koncentracijos-stovyklos-islaisvinimo-metines
# [116] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552989/turnyre-prancuzijoje-triumfavusi-osaka-iskovojo-pirma-titula-po-gimdymo
# [117] Scraping: https://www.lrt.lt/naujienos/lrt-tyrimai/5/2539813/po-tyrimo-itartinus-italu-siulymus-atmetusioms-istaigoms-klausimai-ar-tai-teiseta
# [118] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552814/trumpas-ekonomikos-pergales-yra-jo-nuopelnas-o-del-likusios-dalies-kaltas-bidenas
# [119] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552998/retas-knygas-is-vu-bibliotekos-pavogusiam-kartvelui-siuloma-skirti-virs-3-metu-ikalinima
# [120] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2521549/lietuva-biotechnologiju-srityje-isgarsines-janulaitis-isipareigojau-sazinei-dirbti-cia
# [121] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552458/kaisiadoriu-rajone-nerimas-del-saudyklos-100-m-nuo-sodybos-o-kaimynu-sutikimo-nereikia
# [122] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552921/formule-1-majamyje-be-podiumo-likes-verstappenas-ir-trecia-piastri-pergale-is-eiles
# [123] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552197/nauja-tvarka-del-1-ir-2-centu-mazu-miesteliu-parduotuves-teigia-patiriancios-nepatogumu
# [124] Scraping: https://www.lrt.lt/naujienos/sportas/10/2553039/atkrintamuju-starte-izraelyje-naudingas-jokubaitis-ir-maccabi-pergale
# [125] Scraping: https://www.lrt.lt/naujienos/sveikata/682/2552886/apklausa-6-is-10-gyventoju-palaiko-ideja-uzdrausti-papildomas-priemokas-uz-gydyma
# [126] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552808/daugeja-bandymu-neteisetai-kirsti-siena-is-baltarusijos-vsat-mano-kad-skaicius-augs
# [127] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2550036/lietuvoje-aidejo-perspejimo-sirenos-vyko-sistemos-testavimas
# [128] Scraping: https://www.lrt.lt/naujienos/nuomones/3/2531515/agathos-christie-fenomenas-pribloskiamai-moderni-moteris-po-namu-seimininkes-kauke
# [129] Scraping: https://www.lrt.lt/naujienos/verslas/4/2553122/siaures-investiciju-bankas-skolina-lietuvos-gynybai-400-mln-euru
# [130] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552920/leidimu-negaunanciam-maitinimo-verslui-ministerija-siulo-pataisas-del-patalpu-paskirties
# [131] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2550244/mockus-apie-slapia-pragara-zemeje-vienatve-optimizmas-ir-triju-dienu-dreifas-taifune
# [132] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2543857/kiausialastes-supanciame-skystyje-aptikta-mikroplastiko-kaip-jis-veikia-vaisinguma
# [133] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2550090/uzbekistano-ukininkai-teigia-kad-yra-verciami-atiduoti-zeme-kinijos-imonems
# [134] Scraping: https://www.lrt.lt/naujienos/muzika/680/2552823/kitokia-eurovizija-i-bazeli-besirenkantiems-dainininkams-ir-gerbejams-daug-naujoviu
# [135] Scraping: https://www.lrt.lt/naujienos/sportas/10/2532900/aleknu-disko-metimo-dinastija-tikintis-ubartas-ateity-rezultatai-nustebins-ir-nunes-stoga
# [136] Scraping: https://www.lrt.lt/naujienos/eismas/7/2553092/paluckas-apie-greicio-matuoklius-padiskutuosim-ir-nuspresim
# [137] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552919/pergale-iskovojes-australijos-premjeras-pasikalbejo-su-trumpu
# [138] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2528637/edita-mildazyte-neaisku-kas-yra-didesne-vertybe-buti-gera-gydytoja-ar-gera-mama
# [139] Scraping: https://www.lrt.lt/naujienos/verslas/4/2553057/premjeras-seimos-bustas-galetu-buti-apmokestinamas-nuo-100-tukst-euru
# [140] Scraping: https://www.lrt.lt/naujienos/nuomones/3/2552311/vilma-gudyniene-kodel-kamsteliai-pritvirtinti-prie-buteliu
# [141] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552683/teisingumo-ministras-partnerystes-istatymo-seimas-galetu-imtis-rudens-sesijoje
# [142] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552906/smulkusis-verslas-tikisi-islygu-del-ismaniuju-kasos-aparatu-vmi-zada-laikinai-nebausti
# [143] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552755/vilniaus-evakuacijos-planas-atvere-pandoros-skrynia-ne-tik-kaip-bet-ir-kur-vykti
# [144] Scraping: https://www.lrt.lt/naujienos/sveikata/682/2550825/internete-plinta-klaidinanti-informacija-apie-krutu-patikrinimus-gydytojai-sako-ignoruoti
# [145] Scraping: https://www.lrt.lt/naujienos/sportas/10/2445935/isimintiniausios-2024-metu-sporto-akimirkos-pergales-pralaimejimai-ir-kas-butu-jei
# [146] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552504/pasibaigus-pajamu-deklaravimo-laikotarpiui-to-dar-nepadare-180-tukst-gyventoju
# [147] Scraping: https://www.lrt.lt/naujienos/verslas/4/2529322/tarpininkavimo-mokestis-uz-nuomojama-busta-kas-ir-kada-ji-turi-sumoketi
# [148] Scraping: https://www.lrt.lt/naujienos/verslas/4/2550348/birzos-laikmatis-trumpas-toliau-kritikuoja-fed-vadova
# [149] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2539818/ieva-prudnikovaite-vaikai-dabar-yra-mano-gyvenimo-centras-ir-esme
# [150] Scraping: https://www.lrt.lt/naujienos/tavo-lrt/15/2551834/paskelbti-nacionalinio-diktanto-2025-metu-nugaletojai
# [151] Scraping: https://www.lrt.lt/naujienos/pozicija/679/2552402/dainius-zalimas-geguzes-3-osios-konstitucija-istorines-paraleles-ir-pamokos-siandienai
# [152] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552905/puikiai-tritaskius-laidziusi-pacers-ekipa-rytu-pusfinalio-starte-iveike-cavaliers
# [153] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2553038/demokratu-salygas-del-pazeistos-koalicines-sutarties-paluckas-vadina-karsciavimusi
# [154] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2550728/i-eurovizija-islydetas-katarsis-isvyksta-su-gera-nuotaika-tiki-kad-pasirodys-gerai
# [155] Scraping: https://www.lrt.lt/naujienos/kultura/12/2552465/kulturos-paveldo-komisija-objektu-tvarkymui-reikia-bent-4-kartus-daugiau-finansavimo
# [156] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2551266/lietuvoje-vyko-pilietine-akcija-rankomis-uz-ukraina
# [157] Scraping: https://www.lrt.lt/naujienos/pozicija/679/2553135/stasys-buskevicius-vytauto-parkas-kaune-prarasta-siela
# [158] Scraping: https://www.lrt.lt/naujienos/sportas/10/2445603/bronza-paryziuje-iskovojes-bareikis-dziaugesi-ispudingais-metais-pagaliau-esame-matomi
# [159] Scraping: https://www.lrt.lt/naujienos/nuomones/3/2550671/povilas-aleksandravicius-suprasti-bergoglio-suprasti-prancisku
# [160] Scraping: https://www.lrt.lt/naujienos/verslas/4/2546297/ispeja-del-zmoniu-iprocius-keiciancio-dirbtinio-intelekto-empatijos-stoka-kelia-pavoju
# [161] Scraping: https://www.lrt.lt/naujienos/eismas/7/2550797/vilniu-sukauste-spustys-veluoja-viesasis-transportas
# [162] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2552104/skintos-geles-vazoje-ne-dvi-dienas-o-savaite-kaip-prailginti-narcizu-zydejima
# [163] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2549733/gauti-elektroniniai-laiskai-irodo-nemuno-ausra-melavo-del-rinkimu-islaidu
# [164] Scraping: https://www.lrt.lt/naujienos/kultura/12/2544970/siuolaikinio-sokio-asociacija-skelbia-2024-metu-kurybiniu-pasiekimu-laureatus
# [165] Scraping: https://www.lrt.lt/naujienos/verslas/4/2544384/hostinger-dirbtinio-intelekto-vadovas-tradicinis-programuotojas-tampa-nykstancia-rusimi
# [166] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2463854/vilniaus-oro-uoste-pasitinkami-is-dakaro-sugrize-baciuska-ir-zala
# [167] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2550931/prezidento-patarejas-informacija-apie-jav-kariu-skaiciaus-mazinima-europoje-buvo-paneigta
# [168] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552748/seimas-nepritare-siulymui-narkotines-medziagas-reguliuoti-istatymu-o-ne-ministro-isakymu
# [169] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552724/svente-kedainiuose-vietos-ekipa-triumfavo-rkl-a-diviziono-didziajame-finale
# [170] Scraping: https://www.lrt.lt/naujienos/verslo-pozicija/692/2552156/tomas-bakutis-menuo-rinkose-po-issivadavimo-dienos-stabilumo-daugiau-nerimas-liko
# [171] Scraping: https://www.lrt.lt/naujienos/muzika/680/2552538/eurovizinis-zygis-prasidejo-i-sveicarija-atvyke-katarsio-nariai-pasitikti-plojimais
# [172] Scraping: https://www.lrt.lt/naujienos/svietimas/45/2551994/pietu-miegas-darzeliuose-nebus-privalomas-bet-neaisku-kas-priziures-tvarkos-igyvendinima
# [173] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552707/ruosiantis-keisti-antraja-pensiju-pakopa-nesutariama-ar-tai-nedidins-spaudimo-pirmajai
# [174] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552673/pazeidejas-vilniaus-rajone-islauze-pasienio-uzkarda
# [175] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2540527/saldi-dovana-mamai-liucinos-rimgailes-pistaciju-tiramisu
# [176] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552897/rheinmetall-projektui-25-50-mln-euru-obligaciju-dividendai-2030-aisiais
# [177] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2550752/gaisras-vilniaus-centre-liepsnojo-buvusio-planetariumo-stogas
# [178] Scraping: https://www.lrt.lt/naujienos/verslas/4/2500409/sabutis-atstumine-keliu-rinkliavos-sistema-via-lietuva-galetu-sukurti-pati
# [179] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2551953/motinos-dienos-proga-nauseda-apdovanojo-52-mamas-ir-globejas
# [180] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2525403/kol-taika-sporto-klubas-ar-pramogu-parkas-prasidejus-karui-sleptuve-suomijos-pamokos
# [181] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2545642/nuo-telefonu-spinduliuotes-apsaugancius-aksesuarus-gamina-ir-lietuviai-ar-veikia
# [182] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552927/ziniasklaida-kinijoje-apvirtus-laivams-zuvo-devyni-zmones-dar-kelios-desimtys-suzeista
# [183] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552873/paaiskejo-lietuvos-u23-ir-studentu-fechtavimosi-cempionai
# [184] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2553129/lietuva-stiprina-kontrmobilumo-arsenala-per-10-metu-skirs-virs-milijardo-euru
# [185] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552739/burbiskiu-dvara-zadama-labiau-pritaikyti-lankymui
# [186] Scraping: https://www.lrt.lt/naujienos/svietimas/45/2551902/marijampoles-abiturientas-nuskyne-2-ispudingas-pergales-o-uz-santaupas-perka-18-a-knygas
# [187] Scraping: https://www.lrt.lt/naujienos/pozicija/679/2551813/jurgis-razma-koalicija-kompromituojasi-kompromituodama-ir-valstybes-institutus
# [188] Scraping: https://www.lrt.lt/naujienos/eismas/7/2544659/ar-tiesa-kad-lietuvoje-siais-metais-bus-suremontuoti-tik-47-kilometrai-keliu
# [189] Scraping: https://www.lrt.lt/naujienos/verslas/4/2536631/ekonomikos-istorija-tyrinejantis-profesorius-jav-isskirtinumo-periodas-gali-baigtis
# [190] Scraping: https://www.lrt.lt/naujienos/tavo-lrt/15/2551052/zaidimas-lrt-prototo-pasitikrinkite-zinias-apie-lrt
# [191] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2552065/violeta-palcinskaite-iki-siol-jauciu-to-vieno-saldaus-kasnelio-ir-senu-namu-poreiki
# [192] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2552429/ignalinoje-pastatyta-vytauto-sereno-personazams-bratkoms-skirta-skulptura
# [193] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2550450/kiekvienas-kaimietis-turi-matyt-mane-kauno-teisme-zonos-taisykles-ir-didybes-manija
# [194] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2452632/nestandartinis-butas-senamiestyje-pirmas-namo-aukstas-skirtas-tik-darbo-zonai
# [195] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2533952/geologai-nustate-kad-po-siaures-amerikos-zemynu-esanti-plokste-pamazu-tirpsta
# [196] Scraping: https://www.lrt.lt/naujienos/sportas/10/2553100/pasakinskaite-londone-dar-karta-pagerino-lietuvos-rekorda
# [197] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2553014/skvernelis-siulo-i-seimo-statuta-perkelti-reikalavimus-dirbti-su-islaptinta-informacija
# [198] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552794/pirmasis-kane-o-trofejus-po-bayer-lygiuju-bayern-tapo-vokietijos-cempionais
# [199] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2552551/grupes-katarsis-keliones-i-bazeli-akimirkos
# [200] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552949/ruosiantis-konklavai-pareigunai-ir-darbuotojai-pirmadieni-pasirasys-slaptumo-priesaika
# [201] Scraping: https://www.lrt.lt/naujienos/kultura/12/2543994/veikti-tai-kas-teikia-dziaugsma-albino-elskaus-vaikai-pasakoja-apie-vitrazo-legenda
# [202] Scraping: https://www.lrt.lt/naujienos/kultura/12/2551804/geguzes-kulturines-rekomendacijos-ko-nepraleisti-kvepiant-alyvoms
# [203] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552858/karas-ukrainoje-isw-putinas-aukstina-pasiaukojima-ir-ruosia-visuomene-ilgam-karui
# [204] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2552433/vilniuje-sugriaude-plieniniai-zirgai-baikeriai-oficialiai-atidaro-savo-sezona
# [205] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552777/netiketa-lietuvos-cempiones-isbarste-taskus-pries-lygos-debiutantes
# [206] Scraping: https://www.lrt.lt/naujienos/verslas/4/2550704/jau-mateme-tai-estijoje-po-pensiju-reformos-ekonomika-buvo-uzpilta-pinigais
# [207] Scraping: https://www.lrt.lt/naujienos/verslas/4/2550182/ryanair-keicia-bagazo-taisykles-ju-nesilaikantiems-iki-70-euru-bauda
# [208] Scraping: https://www.lrt.lt/naujienos/svietimas/45/2552032/triju-jaunu-mokytoju-istorijos-kaip-noro-mokyti-nesugriove-net-mylincio-zmogaus-klasta
# [209] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2553063/balandziai-mirtys-ir-davinys-kaip-per-amzius-keitesi-popieziaus-rinkimai
# [210] Scraping: https://www.lrt.lt/naujienos/verslas/4/2545372/rasti-laisva-sodyba-poilsiui-vasara-galvos-skausmas-mokamos-ir-trizenkles-sumos
# [211] Scraping: https://www.lrt.lt/naujienos/sportas/10/2445872/auksinius-metus-apzvelgusi-meilutyte-atsivere-tiek-metu-neisvengiu-vis-tu-paciu-klaidu
# [212] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552987/ministerija-siulo-palikti-pvm-lengvata-sildymui-ja-didinti-iki-12-proc
# [213] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552590/sekmadienis-geru-oru-nedziugins-o-kita-savaite-gali-atnesti-ir-salnas
# [214] Scraping: https://www.lrt.lt/naujienos/kultura/12/2539805/kulturos-istorike-pukelyte-karo-metu-sudetingiausia-elgtis-taip-kaip-reikalauja-sazine
# [215] Scraping: https://www.lrt.lt/naujienos/verslas/4/2551733/nuvirtusi-iranga-prispaude-du-vejo-jegainiu-statybininkus
# [216] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552787/sirinskiene-koalicija-nemaloni-bet-dudenas-per-maza-paukste-kad-pasitrauktume
# [217] Scraping: https://www.lrt.lt/naujienos/pozicija/679/2550124/emilija-svobaite-uzsienieciu-darbas-lietuvoje-esame-kolegos-ar-konkurentai
# [218] Scraping: https://www.lrt.lt/naujienos/eismas/7/2524120/uzkliuvo-prie-daugiabucio-ikurti-elektromobiliu-krovikliai-nelieka-keliu-parkavimo-vietu
# [219] Scraping: https://www.lrt.lt/naujienos/mokslas-ir-it/11/2546519/baltieji-rumai-atnaujino-covid-19-puslapi-teigia-kad-virusas-sukurtas-laboratorijoje
# [220] Scraping: https://www.lrt.lt/naujienos/sveikata/682/2552964/sam-tvarka-registruoti-ne-pas-specialista-o-i-kabineta-butu-taikoma-tik-esant-skubai
# [221] Scraping: https://www.lrt.lt/naujienos/tavo-lrt/15/2551424/zaidimas-lrt-prototo-ka-reiskia-hario-poterio-pavarde
# [222] Scraping: https://www.lrt.lt/naujienos/eismas/7/2549198/vandalai-siaubia-greicio-matuoklius-padega-saudo-ir-net-sprogdina
# [223] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2545017/pasaulio-nematanti-vaida-ji-jaucia-jautri-jos-daina-varzysis-silpnaregiu-eurovizijoje
# [224] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2548104/liudnai-grazi-egles-meiles-istorija-vaiku-susilaukti-negalejo-ir-tapo-geraja-pamote
# [225] Scraping: https://www.lrt.lt/naujienos/sportas/10/2446970/sventes-ir-treniruotes-derinanti-banevic-apie-tikejima-sidabrini-paryziu-ir-2024-metus
# [226] Scraping: https://www.lrt.lt/naujienos/kultura/12/2549643/dizainere-kotryna-kvasyte-augdama-dideleje-seimoje-jutau-poreiki-buti-pastebeta
# [227] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552845/koalicine-taryba-renkasi-aptarti-mokesciu-antros-pakopos-priemoku-uz-sveikatos-paslaugas
# [228] Scraping: https://www.lrt.lt/naujienos/kultura/12/2551641/klaipedos-valstybinio-muzikinio-teatro-interjerui-prestizinis-apdovanojimas
# [229] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2552147/psichologe-pataria-kaip-suteikti-pagalba-mamai-taip-kad-ja-priimtu
# [230] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2553071/kodel-vaikai-pradeda-vartoti-psichoaktyvias-medziagas-pastumeja-ir-smalsumas-ir-nerimas
# [231] Scraping: https://www.lrt.lt/naujienos/eismas/7/2552940/tyrimas-isigyti-elektromobili-labiausiai-motyvuoja-kompensacijos-ir-nemokamas-parkavimas
# [232] Scraping: https://www.lrt.lt/naujienos/fotogalerijos/685/2552431/grupes-katarsis-palydetuves-vilniaus-oro-uoste
# [233] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552820/bendzius-isirase-i-sasario-klubo-metrascius-tapo-antru-rezultatyviausiu-istorijoje
# [234] Scraping: https://www.lrt.lt/naujienos/verslas/4/2552961/elektrum-lietuvai-turi-nauja-vadove
# [235] Scraping: https://www.lrt.lt/naujienos/sportas/10/2535981/alekna-su-jordanu-lygines-jusis-po-kosminio-pasaulio-rekordo-virs-zmogaus-galimybiu-ribu
# [236] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2551981/bibliotekos-ant-ratu-architekte-tai-maziausias-mano-objektas-su-dideliu-atgaliniu-rysiu
# [237] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2552604/lietuvos-pasienyje-su-baltarusija-apgrezti-45-neteiseti-migrantai
# [238] Scraping: https://www.lrt.lt/naujienos/lietuvoje/2/2547784/20-o-gal-tik-5-kiek-tukstanciu-protestuotoju-pries-nt-mokesti-susirinko-vilniuje
# [239] Scraping: https://www.lrt.lt/naujienos/pasaulyje/6/2552746/trumpas-teigia-kad-nesiruosia-kandidatuoti-treciajai-kadencijai
# [240] Scraping: https://www.lrt.lt/naujienos/sportas/10/2551738/auksines-zvaigzdes-ivertinimo-sulauke-jaunieji-sportininkai-tokie-apdovanojimai-motyvuoja
# [241] Scraping: https://www.lrt.lt/naujienos/kultura/12/2545154/parodose-16-ojo-amziaus-leonpolio-dvare-nuo-paskutines-vakarienes-iki-moters-kuno
# [242] Scraping: https://www.lrt.lt/naujienos/tavo-lrt/15/2552830/zaidimas-lrt-prototo-pasitikrinkite-zinias-apie-ivairius-miestus
# [243] Scraping: https://www.lrt.lt/naujienos/kultura/12/2538658/ciurlionio-biografijos-tyrinetoja-siwuda-kai-kuriems-lietuviams-jis-pernelyg-lenkiskas
# [244] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552801/velyvo-spurto-neuzteko-siaulieciai-krito-jonavoje
# [245] Scraping: https://www.lrt.lt/naujienos/sportas/10/2552664/po-nesekmes-su-sirgaliais-emocingai-bendraves-ceburinas-turime-jausti-atsakomybe
# [246] Scraping: https://www.lrt.lt/naujienos/laisvalaikis/13/2547774/kainos-kaip-sveicarijoje-kiek-keliautojai-agnei-kainavo-savaitgalio-kelione-i-amsterdama
# [247] Scraping: https://www.lrt.lt/naujienos/tavo-lrt/15/1927823/lrt-zurnalistikos-patikimumas-ivertintas-tarptautiniu-sertifikatu
# [248] Scraping: https://www.lrt.lt/naujienos/sportas/10/2532458/su-lietuvos-biatlonininkais-po-europa-keliaujantis-juozas-nakvyne-uzsakau-metams-i-prieki
# [249] Scraping: https://www.lrt.lt/naujienos/sportas/10/2446941/elite-isitvirtinusi-teterevkova-plaukiku-pasirodymu-nevertino-nezinai-kaip-jie-jauciasi
# [250] Scraping: https://www.lrt.lt/naujienos/nuomones/3/2550504/gintautas-mazeikis-trumpo-simtadienis-greitejimas-i-chaosa
# Saved lrt.lt articles to lrt_articles.csv

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup

# Load CSV
df = pd.read_csv("/content/drive/MyDrive/lrt_articles.csv", encoding="utf-8")

# Basic Lithuanian stopwords list
lithuanian_stopwords = set([
    "ir", "kad", "bet", "nes", "tai", "taip", "čia", "aš", "tu", "jis", "ji",
    "mes", "jūs", "jie", "jos", "man", "tau", "jam", "jai", "mums", "jums",
    "juos", "jas", "ar", "kur", "kada", "kaip", "kas", "kuo", "kodėl", "jog",
    "tą", "tas", "tie", "tiek", "šitą", "šis", "šita", "ši", "šiuos", "su",
    "be", "nuo", "iki", "už", "ant", "po", "per", "apie", "prie", "už"
])

def clean_text(text):
    # Remove HTML tags
    text = BeautifulSoup(str(text), "html.parser").get_text()

    # Remove known junk phrases
    junk_patterns = [
        r"skaitykite daugiau.*",
        r"daugiau straipsnių.*",
        r"nuotraukos.*",
        r"video.*"
    ]
    for pattern in junk_patterns:
        text = re.sub(pattern, "", text, flags=re.IGNORECASE)

    # Remove non-alphabetic characters except Lithuanian letters
    text = re.sub(r"[^a-zA-ZąčęėįšųūžĄČĘĖĮŠŲŪŽ\s]", "", text)

    # Convert to lowercase after filtering
    text = text.lower()

    # Remove extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    # Remove stopwords
    words = text.split()
    filtered = [word for word in words if word not in lithuanian_stopwords]

    return " ".join(filtered)

# Apply cleaning
df["clean_text"] = df["text"].astype(str).apply(clean_text)

# Filter too-short entries
df = df[df["clean_text"].apply(lambda x: len(x.split()) >= 50)]

# Save
df[["title", "url", "clean_text"]].to_csv("/content/drive/MyDrive/lrt_articles_cleaned.csv", index=False, encoding="utf-8")

print("Cleaned and saved to lrt_articles_cleaned.csv")
# Out:
# Cleaned and saved to lrt_articles_cleaned.csv

# %%
# !pip install sentence-transformers faiss-cpu transformers datasets

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# Load and embed cleaned article data
df = pd.read_csv("/content/drive/MyDrive/lrt_articles_cleaned.csv")

texts = df["clean_text"].tolist()
model_name = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
embedder = SentenceTransformer(model_name)

print("Generating embeddings...")
embeddings = embedder.encode(texts, convert_to_numpy=True)

# Build FAISS index
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)
print("Stored embeddings in FAISS index.")
# Out:
# Generating embeddings...
# Stored embeddings in FAISS index.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# Model
llm_name = "google/flan-t5-small"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(llm_name)
model = AutoModelForSeq2SeqLM.from_pretrained(llm_name)

# Create generator pipeline
generator = pipeline("text2text-generation", model=model, tokenizer=tokenizer)

# RAG-style query function
def query_rag(question, top_k=5, max_context_chars=1500):
    query_embedding = embedder.encode([question])
    D, I = index.search(query_embedding, top_k)
    retrieved_docs = [texts[i] for i in I[0]]

    context = "\n\n".join(retrieved_docs)
    context = context[:max_context_chars]

    prompt = f"Atsakyk i klausima remdamasis sia informacija:\n{context}\n\nKlausimas: {question}"

    result = generator(prompt, max_new_tokens=200)[0]["generated_text"]
    print("\n--- RESPONSE ---")
    print(result.strip())
# Out:
# Device set to use cpu

# %%
query_rag("Ką Ukraina paskelbė apie rusų naikintuvą?")
# Out:
# --- RESPONSE ---
# Atsakyk i klausima remdamasis sia informacija: kremliaus urnalistas pavelas zarubinas rusijos valstybiniame televizijos kanale rossija paskelb dokumentin film kuriame vladimiras putinas pabr rusijos vidaus auditorijos param karui propagavo pasiaukojimo ideal karo nam frontuose greiiausiai siekdamas paruoti rusijos visuomen ilgesniam karui  invazij
